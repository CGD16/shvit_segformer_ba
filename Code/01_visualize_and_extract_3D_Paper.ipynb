# %%
# import pprint
# from zipfile import ZipFile

# path = "./PythonTools-3.7.0-py2.py3-none-any.whl"
# names = ZipFile(path).namelist()
# pprint.pprint(names)

# %%
from pathlib import Path
import json

import pydicom as dicom
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt
import matplotlib.animation as animation

import slicerio # https://pypi.org/project/slicerio/

from PythonTools.rek2py import rek2py
# from PythonTools.raw2dicom import raw2dicom

# %%
path_variable = "/mnt/d/Datasets/shoes/"
save_path = path_variable + "images_3d/"

# %%
N_CONVS = 2

MODELNAME = f"SegFormer_{N_CONVS}conv_4seg_v2"
# MODELNAME = "SegFormer"
# SHVIT_SEGFORMER = False

NUM_LAYERS = 10


# DEPTH, HEIGHT, WIDTH = 80, 80, 80 
# DEPTH, HEIGHT, WIDTH = 112, 112, 112 
# DEPTH, HEIGHT, WIDTH = 128, 128, 128 
# DEPTH, HEIGHT, WIDTH = 160, 160, 160 
# DEPTH, HEIGHT, WIDTH = 192, 192, 192 
# DEPTH, HEIGHT, WIDTH = 196, 196, 196
# DEPTH, HEIGHT, WIDTH = 224, 224, 224
# DEPTH, HEIGHT, WIDTH = 240, 240, 240
DEPTH, HEIGHT, WIDTH = 256, 256, 256
# DEPTH, HEIGHT, WIDTH = 272, 272, 272
# DEPTH, HEIGHT, WIDTH = 288, 288, 288
# DEPTH, HEIGHT, WIDTH = 320, 320, 320
# DEPTH, HEIGHT, WIDTH = 336, 336, 336
# DEPTH, HEIGHT, WIDTH = 352, 352, 352
# DEPTH, HEIGHT, WIDTH = 448, 448, 448
# DEPTH, HEIGHT, WIDTH = 464, 464, 464
# DEPTH, HEIGHT, WIDTH = 480, 480, 480
# DEPTH, HEIGHT, WIDTH = 512, 512, 512
# DEPTH, HEIGHT, WIDTH = 896, 896, 896

factor = 2**N_CONVS

# %%
def list_all_files(directory, ext):

    directory_path = Path(directory)
    # List all files in the directory and subdirectories
    all_files = list(directory_path.rglob(ext))  

    # Filter out directories
    files = [file for file in all_files if file.is_file()]
    return files


# Example usage
directory = path_variable + "_volumes/"
files = list_all_files(directory, "*.rek")
files
# Out:
# [PosixPath('/mnt/d/Datasets/shoes/_volumes/Adidas_Martin-weiss.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Adidas_Martin.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Bruschi_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Camper_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-34_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-36_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-39_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-42_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Herrenschuh_43p5_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Lidl_43_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Lloyd_38_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Lloyd_pink_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Lloyd_weiss_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/McKinley_Anton_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Mustang-Sch-Navy-Metalli-35_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Mustang-Sch-Navy-Metalli-40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Mustang-Sch-Navy-Metalli_31_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Mustang-Sch-Navy-Metalli_36_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Mustang-Sch-Navy-Metalli_37_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Pertolio-dunkelbraun_43_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Petrolio-Sch-dunkelbraun_42_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Petrolio-Sch-dunkelbraun_44_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Petrolio-Sch-dunkelbraun_46_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/PetrolioSch-40-float_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Puma_38_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Puma_Silver_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Puma_White_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Schuh_Martin_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Shoepassion_40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Shoepassion_45_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Shoepassion_Herren_40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Sneaker_Dana_Nike.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Sneaker_Dana_Puma_Flyer.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Stiefel-XY_40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Tamaris-Pump-Schwarz-38_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Tamaris-Pump-schwarz_36_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Tamaris-Pump-Schwarz_39_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Tamaris-Pump-schwarz_40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Tamaris-Pump-schwarz_42_down2_2_2.rek')]

# %%
# after run check how shoes are oriented in the box; repeat only the files where shoes are not displayed from the side - modify transpose
rotate_shoes = [path_variable + "_volumes/Adidas_Martin.rek",path_variable + "_volumes/Citywalk-sit-taupe-34_down2_2_2.rek", 
                path_variable + "_volumes/Citywalk-sit-taupe-36_down2_2_2.rek", path_variable + "_volumes/Citywalk-sit-taupe-40_down2_2_2.rek", 
                path_variable + "_volumes/Schuh_Martin_down2_2_2.rek", path_variable + "_volumes/Sneaker_Dana_Nike.rek",
                path_variable + "_volumes/Sneaker_Dana_Puma_Flyer.rek"]

# Convert to pathlib.Path objects
rotate_shoes = [Path(folder) for folder in rotate_shoes]
rotate_shoes
# Out:
# [PosixPath('/mnt/d/Datasets/shoes/_volumes/Adidas_Martin.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-34_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-36_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Citywalk-sit-taupe-40_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Schuh_Martin_down2_2_2.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Sneaker_Dana_Nike.rek'),
#  PosixPath('/mnt/d/Datasets/shoes/_volumes/Sneaker_Dana_Puma_Flyer.rek')]

# %%
from scipy import ndimage

def resize_volume(volume, depth=DEPTH, height=HEIGHT, width=WIDTH, factor=1):
    
    (vol_depth, vol_height, vol_width) = volume.shape
    
    depth_factor = depth/vol_depth/factor
    height_factor = height/vol_height/factor
    width_factor = width/vol_width/factor
    
    print("xx"*20, volume.shape)
    print("xx"*20, depth_factor, height_factor, width_factor)
    
    volume = ndimage.zoom(volume, (depth_factor, height_factor, width_factor), order=1)
    print("xx"*20, volume.shape)
    
    return volume

# %%
def saveVolumes(folder, files):
    for file in files:
        
        # Get the file name without extension
        file_path  = Path(file)
        filename =  file_path.stem
        print(filename)

        # dicomdata = raw2dicom(image=volume, ezrt_header=header)
        header, volume = rek2py(filepath=file, switch_order=True)
        print(volume.shape)
        
        _min, _max = 1, 99
        if "PetrolioSch-40-float_down2_2_2" in str(file):
            _min, _max = 4, 99            
        
        values = volume.flatten()
        vmin = np.percentile(values, _min)
        vmax = np.percentile(values, _max)
        
        scale = (volume.astype(np.float64) - vmin)/(vmax-vmin + 1e-5)
        scale = np.clip(scale, 0, 1).astype(np.float32)
    
        # createAnimation(filename, volume)
        if file in rotate_shoes:
            orientation = (1,2,0)
        else:
            orientation = (2,1,0)
            
        volume = scale.transpose(orientation)      
        volume = resize_volume(volume)
        
        folder_path = Path(folder)
        folder_path.mkdir(parents=True, exist_ok=True)
        file_path = f"{folder_path.joinpath(filename)}" #.npz"
        # np.savez_compressed(file_path, volume)
        np.save(file_path, volume)
    

target_directory = f"{save_path}images_3d_{MODELNAME}_{DEPTH}x{HEIGHT}x{WIDTH}/volumes"
# saveVolumes(target_directory, files[:5])

# %%
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "vscode"


def plotVolume(folder, file):
    
    # Get the file name without extension
    file_path  = Path(file)
    filename =  file_path.stem
    print(filename)    
    
    # Load 3D numpy array
    shoe_volume = np.load(f"{save_path}images_3d_{MODELNAME}_{DEPTH}x{HEIGHT}x{WIDTH}/volumes/{filename}.npy")  # Ensure this is a (128,128,128) NumPy array

    # Create the 3D grid
    x, y, z = np.mgrid[:DEPTH, :HEIGHT, :WIDTH]

    # Create the volume plot
    fig = go.Figure(data=go.Volume(
        x=x.flatten(),
        y=y.flatten(),
        z=z.flatten(),
        value=shoe_volume.flatten().astype(np.float16),
        opacity=0.1,  # Adjust for visibility
        surface_count=30,  # Number of isosurfaces
        colorscale="gray"  # Set grayscale colormap
    ))

    # Show the figure
    fig.update_layout(
        width=1000,  # Set the width in pixels
        height=1000,   # Set the height in pixels
        scene=dict(
            xaxis=dict(showbackground=False),
            yaxis=dict(showbackground=False),
            zaxis=dict(showbackground=False),
        )
    )

    filename = f"plot_{DEPTH}x{HEIGHT}x{WIDTH}_{filename}.html"
    folder_path = Path(folder)
    folder_path.mkdir(parents=True, exist_ok=True)
    file_path = f"{folder_path.joinpath(filename)}"

    print(file_path)
    fig.write_html(file_path)
    
    
plot_directory = f"{save_path}plots"
volume_directory = f"{save_path}images_3d_{MODELNAME}_{DEPTH}x{HEIGHT}x{WIDTH}/volumes"
files = list_all_files(volume_directory, "*.npy")
    
for file in files[:5]:
    plotVolume(plot_directory, file)
# Out:
# Adidas_Martin-weiss
# /mnt/d/Datasets/shoes/images_3d/plots/plot_256x256x256_Adidas_Martin-weiss.html
# Adidas_Martin
# /mnt/d/Datasets/shoes/images_3d/plots/plot_256x256x256_Adidas_Martin.html
# Bruschi_down2_2_2
# /mnt/d/Datasets/shoes/images_3d/plots/plot_256x256x256_Bruschi_down2_2_2.html
# Camper_down2_2_2
# /mnt/d/Datasets/shoes/images_3d/plots/plot_256x256x256_Camper_down2_2_2.html
# Citywalk-sit-taupe-34_down2_2_2
# /mnt/d/Datasets/shoes/images_3d/plots/plot_256x256x256_Citywalk-sit-taupe-34_down2_2_2.html

# %%
directory = path_variable + "annotations/"
files = list_all_files(directory, "*.seg.nrrd")

for file in files:
    
    # Get the file name without extension
    file_path  = Path(file)
    filename =  file_path.stem
    print(filename)    

    segmentation = slicerio.read_segmentation(str(file), skip_voxels=True)

    number_of_segments = len(segmentation["segments"])
    print(f"Number of segments: {number_of_segments}")

    segment_names = slicerio.segment_names(segmentation)
    print(f"Segment names: {', '.join(segment_names)}")

# %% [markdown]
# ## Extract image and masks for layer xyz of all shoes

# %%
rotate_shoes = [path_variable + "_annotations/Adidas_Martin.seg.nrrd", path_variable + "_annotations/Citywalk 34.seg.nrrd", 
                path_variable + "_annotations/Citywalk 36.seg.nrrd", path_variable + "_annotations/Citywalk 40.seg.nrrd", 
                path_variable + "_annotations/Schuh_Martin_down2_2_2.seg.nrrd", path_variable + "_annotations/Sneaker_Dana_Nike.seg.nrrd", 
                path_variable + "_annotations/Sneaker_Dana_Puma_Flyer.seg.nrrd"]

rotate_shoes = [Path(folder) for folder in rotate_shoes]

class_dict = {"Karton": 1, "Außensohle": 2, "Innensohle": 3, "Obermaterial": 4, "Zunge": 5, "Füllmaterial": 6}

# %%
key = "Zunge"
class_dict[key]
# Out:
# 5

# %%
def createMask(folder, file):

    segmentation_info = slicerio.read_segmentation(file)
    segment_names = slicerio.segment_names(segmentation_info) # Get semgnet_names where 3D Slicer

    segment_names_to_labels = []
    for j, sn in enumerate(segment_names):
        segment_names_to_labels.append((sn, j+1)) 
        if not segment_names_to_labels:
            continue
        
    # Numbering according to Segmented labels of 3D Slicer
    # data_Karton         = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Karton"][0]])
    data_Aussensohle    = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Auensohle"][0]])
    data_Innensohle     = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Innensohle"][0]])
    data_Obermaterial   = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Obermaterial"][0]])
    # data_Zunge          = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Zunge"][0]])
    # data_Fuellmaterial  = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Fllmaterial"][0]])

    # data_Innenvolumen1  = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Innenvolumen_1"][0]])
    # data_Innenvolumen2  = slicerio.extract_segments(segmentation_info, [[item for item in segment_names_to_labels if item[0] == "Innenvolumen_2"][0]])
    

    if file in rotate_shoes:
        orientation = (1,0,2) # these shoes need different orientation / transpose
    else:
        orientation = (0,1,2) # normal orientation for all shoes
            
    print(orientation)
    # data_Karton        = data_Karton.get("voxels").transpose(orientation)            
    data_Aussensohle   = data_Aussensohle.get("voxels").transpose(orientation)            
    data_Obermaterial  = data_Obermaterial.get("voxels").transpose(orientation)            
    data_Innensohle    = data_Innensohle.get("voxels").transpose(orientation)            
    # data_Zunge         = data_Zunge.get("voxels").transpose(orientation)            
    # data_Fuellmaterial = data_Fuellmaterial.get("voxels").transpose(orientation)            

    # data_Innenvolumen1 = data_Innenvolumen1.get("voxels").transpose(orientation)            
    # data_Innenvolumen2 = data_Innenvolumen2.get("voxels").transpose(orientation)            
        
    # print(np.unique(data_Karton))
    # print(np.unique(data_Aussensohle))
    # print(np.unique(data_Obermaterial))
    # print(np.unique(data_Innensohle))
    # print(np.unique(data_Zunge))
    # print(np.unique(data_Fuellmaterial))
    
    # data_Karton = resize_volume(data_Karton, factor=factor)
    data_Aussensohle = resize_volume(data_Aussensohle, factor=factor)
    data_Obermaterial = resize_volume(data_Obermaterial, factor=factor)
    data_Innensohle = resize_volume(data_Innensohle, factor=factor)
    # data_Zunge = resize_volume(data_Zunge, factor=factor)
    # data_Fuellmaterial = resize_volume(data_Fuellmaterial, factor=factor)

    # data_Innenvolumen1 = resize_volume(data_Innenvolumen1, factor=factor)
    # data_Innenvolumen2 = resize_volume(data_Innenvolumen2, factor=factor)


    # # Create an empty volume filled with zeros (3 segments)
    # final_volume = np.zeros(data_Karton.shape, dtype=np.uint8)
    # final_volume[(data_Karton + data_Fuellmaterial) > 0] = 1
    # final_volume[(data_Aussensohle + data_Innensohle + data_Obermaterial + data_Zunge) > 0] = 2

    # # Create an empty volume filled with zeros (2 segments)
    # final_volume = np.zeros(data_Innenvolumen1.shape, dtype=np.uint8)
    # final_volume[(data_Innenvolumen1 + data_Innenvolumen2) > 0] = 1

    # # Create an empty volume filled with zeros (3 segments)
    final_volume = np.zeros(data_Aussensohle.shape, dtype=np.uint8)
    final_volume[(data_Aussensohle) > 0] = 1
    final_volume[(data_Innensohle) > 0] = 2
    final_volume[(data_Obermaterial) > 0] = 3

    print(final_volume.shape, np.unique(final_volume))
    
    
    if file.suffix:  # Check again if there's at least one suffix
        filename =  file.stem

        if file.suffix:  # Check again if there's at least one suffix
            filename = filename.rsplit('.', 1)[0]  # Remove the last part after the last '.'
    print(filename)  
    
    folder_path = Path(folder)
    folder_path.mkdir(parents=True, exist_ok=True)
    file_path = f"{folder_path.joinpath(filename)}" #.npz"
    # np.savez_compressed(file_path, volume)
    np.save(file_path, final_volume)

        
    
    
# extract mask information  
target_directory = f"{save_path}images_3d_{MODELNAME}_{DEPTH}x{HEIGHT}x{WIDTH}/masks"
annotation_directory = path_variable + "_annotations/"

files = list_all_files(annotation_directory, "*.seg.nrrd")
for file in files:
    print(file)
    createMask(target_directory, file)
# Out:
# /mnt/d/Datasets/shoes/_annotations/Adidas_Martin-weiss.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (988, 988, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06477732793522267 0.06477732793522267 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (988, 988, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06477732793522267 0.06477732793522267 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (988, 988, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06477732793522267 0.06477732793522267 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Adidas_Martin-weiss
# /mnt/d/Datasets/shoes/_annotations/Adidas_Martin.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Adidas_Martin
# /mnt/d/Datasets/shoes/_annotations/Bruschi_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (475, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.13473684210526315 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (475, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.13473684210526315 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (475, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.13473684210526315 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Bruschi_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Camper_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (425, 675, 880)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15058823529411763 0.09481481481481481 0.07272727272727272
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (425, 675, 880)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15058823529411763 0.09481481481481481 0.07272727272727272
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (425, 675, 880)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15058823529411763 0.09481481481481481 0.07272727272727272
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Camper_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Citywalk 34.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1068, 1068, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.0599250936329588 0.0599250936329588 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1068, 1068, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.0599250936329588 0.0599250936329588 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1068, 1068, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.0599250936329588 0.0599250936329588 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Citywalk 34
# /mnt/d/Datasets/shoes/_annotations/Citywalk 36.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1071, 1068, 1056)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.059757236227824466 0.0599250936329588 0.06060606060606061
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1071, 1068, 1056)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.059757236227824466 0.0599250936329588 0.06060606060606061
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1071, 1068, 1056)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.059757236227824466 0.0599250936329588 0.06060606060606061
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Citywalk 36
# /mnt/d/Datasets/shoes/_annotations/Citywalk 39.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1019, 1019, 1043)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06280667320902845 0.06280667320902845 0.061361457334611694
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1019, 1019, 1043)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06280667320902845 0.06280667320902845 0.061361457334611694
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1019, 1019, 1043)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06280667320902845 0.06280667320902845 0.061361457334611694
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Citywalk 39
# /mnt/d/Datasets/shoes/_annotations/Citywalk 40.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1068, 1068, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.0599250936329588 0.0599250936329588 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1068, 1068, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.0599250936329588 0.0599250936329588 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1068, 1068, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.0599250936329588 0.0599250936329588 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Citywalk 40
# /mnt/d/Datasets/shoes/_annotations/Citywalk 42.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Citywalk 42
# /mnt/d/Datasets/shoes/_annotations/Herrenschuh_43p5_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (500, 700, 888)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.128 0.09142857142857143 0.07207207207207207
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (500, 700, 888)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.128 0.09142857142857143 0.07207207207207207
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (500, 700, 888)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.128 0.09142857142857143 0.07207207207207207
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Herrenschuh_43p5_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Lidl_43_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 675, 880)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09481481481481481 0.07272727272727272
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 675, 880)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09481481481481481 0.07272727272727272
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 675, 880)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09481481481481481 0.07272727272727272
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Lidl_43_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Lloyd_38_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (375, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.17066666666666666 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (375, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.17066666666666666 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (375, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.17066666666666666 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Lloyd_38_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Lloyd_pink_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (420, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.1523809523809524 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (420, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.1523809523809524 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (420, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.1523809523809524 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Lloyd_pink_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Lloyd_weiss_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Lloyd_weiss_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/McKinley_Anton.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# McKinley_Anton
# /mnt/d/Datasets/shoes/_annotations/Mustang 31.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1130)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05663716814159292
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1130)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05663716814159292
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1130)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05663716814159292
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Mustang 31
# /mnt/d/Datasets/shoes/_annotations/Mustang 35.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1013)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.0631786771964462
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1013)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.0631786771964462
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1013)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.0631786771964462
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Mustang 35
# /mnt/d/Datasets/shoes/_annotations/Mustang 36.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Mustang 36
# /mnt/d/Datasets/shoes/_annotations/Mustang 37.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (969, 969, 1071)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06604747162022703 0.06604747162022703 0.059757236227824466
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (969, 969, 1071)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06604747162022703 0.06604747162022703 0.059757236227824466
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (969, 969, 1071)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06604747162022703 0.06604747162022703 0.059757236227824466
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Mustang 37
# /mnt/d/Datasets/shoes/_annotations/Mustang 40.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (1018, 1018, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06286836935166994 0.06286836935166994 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Mustang 40
# /mnt/d/Datasets/shoes/_annotations/Petrolio 40.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (554, 678, 1090)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.11552346570397112 0.0943952802359882 0.05871559633027523
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (554, 678, 1090)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.11552346570397112 0.0943952802359882 0.05871559633027523
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (554, 678, 1090)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.11552346570397112 0.0943952802359882 0.05871559633027523
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Petrolio 40
# /mnt/d/Datasets/shoes/_annotations/Petrolio 42.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Petrolio 42
# /mnt/d/Datasets/shoes/_annotations/Petrolio 43.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Petrolio 43
# /mnt/d/Datasets/shoes/_annotations/Petrolio 44.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Petrolio 44
# /mnt/d/Datasets/shoes/_annotations/Petrolio 46.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1102)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05807622504537205
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1102)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05807622504537205
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1102)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.05807622504537205
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Petrolio 46
# /mnt/d/Datasets/shoes/_annotations/Puma_38_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (375, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.17066666666666666 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (375, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.17066666666666666 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (375, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.17066666666666666 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Puma_38_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Puma_Silver_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (400, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.16 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (400, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.16 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (400, 675, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.16 0.09481481481481481 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Puma_Silver_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Puma_White_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (400, 775, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.16 0.08258064516129032 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (400, 775, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.16 0.08258064516129032 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (400, 775, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.16 0.08258064516129032 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Puma_White_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Schuh_Martin_down2_2_2.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (990, 990, 993)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06464646464646465 0.06464646464646465 0.06445115810674723
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Schuh_Martin_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Shoepassion_40_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Shoepassion_40_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Shoepassion_45_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (425, 700, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15058823529411763 0.09142857142857143 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (425, 700, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15058823529411763 0.09142857142857143 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (425, 700, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15058823529411763 0.09142857142857143 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Shoepassion_45_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Shoepassion_Herren_40_down2_2_2.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (450, 650, 876)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14222222222222222 0.09846153846153846 0.0730593607305936
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Shoepassion_Herren_40_down2_2_2
# /mnt/d/Datasets/shoes/_annotations/Sneaker_Dana_Nike.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (445, 685, 970)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14382022471910114 0.09343065693430656 0.06597938144329897
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (445, 685, 970)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14382022471910114 0.09343065693430656 0.06597938144329897
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (445, 685, 970)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.14382022471910114 0.09343065693430656 0.06597938144329897
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Sneaker_Dana_Nike
# /mnt/d/Datasets/shoes/_annotations/Sneaker_Dana_Puma_Flyer.seg.nrrd
# (1, 0, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (410, 685, 958)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15609756097560976 0.09343065693430656 0.06680584551148225
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (410, 685, 958)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15609756097560976 0.09343065693430656 0.06680584551148225
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (410, 685, 958)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.15609756097560976 0.09343065693430656 0.06680584551148225
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# Sneaker_Dana_Puma_Flyer
# /mnt/d/Datasets/shoes/_annotations/StiefelXY.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1101)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05812897366030881
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# StiefelXY
# /mnt/d/Datasets/shoes/_annotations/TamarisPump 36.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 896)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.07142857142857142
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 896)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.07142857142857142
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 896)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.07142857142857142
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# TamarisPump 36
# /mnt/d/Datasets/shoes/_annotations/TamarisPump 38.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1129)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.0566873339238264
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1129)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.0566873339238264
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1129)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.0566873339238264
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# TamarisPump 38
# /mnt/d/Datasets/shoes/_annotations/TamarisPump 39.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (972, 970, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06584362139917696 0.06597938144329897 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (972, 970, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06584362139917696 0.06597938144329897 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (972, 970, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06584362139917696 0.06597938144329897 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# TamarisPump 39
# /mnt/d/Datasets/shoes/_annotations/TamarisPump 40.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (968, 968, 1042)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06611570247933884 0.06611570247933884 0.061420345489443376
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# TamarisPump 40
# /mnt/d/Datasets/shoes/_annotations/TamarisPump 42.seg.nrrd
# (0, 1, 2)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1072)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05970149253731343
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1072)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05970149253731343
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (971, 971, 1072)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx 0.06591143151390319 0.06591143151390319 0.05970149253731343
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx (64, 64, 64)
# (64, 64, 64) [0 1 2 3]
# TamarisPump 42
